# %% [markdown]
# Data shows that the best neighborhood is between mainly Bloomfield and Squirrel Hill South, with Bloomfield having 3 more Bike Accessible roads.

# %% [markdown]
# Had to manually figure out the neighborhoods for these entries:
# Resevoir - Highland Park
# Highland - East Liberty
# Thomas - Point Breeze
# Brereton - Polish Hill
# Braddock - Point Breeze/Squirrel Hills South
# Sennot st - Central Oakland
# Highland - East Liberty
# O'Hara - Central Oakland
# Allegheny circle - Central Allegheny
# 3rd Ave - Central Business District
# South Side Neighborway - South Side
# Lawranceville Neighborway - Central Lawranceville
# Marshall - Marshall-Shadeland/Brighton Heights
# Bloomfield Friendship Neighborway - Bloomfield
# Euclid Neighborway - East Liberty
# Hazelwood Gold Neighborway - Hazelwood
# Reynolds street - Point Breeze
# California - California-Kirkbride
# Federal - North Shore

# %%
## import pandas as pd
import pandas as pd
import requests
import time

# Manually added neighborhoods (all lowercase)
manual_neighborhoods = {
    "resevoir dr": "Highland Park",
    "highland ave": "East Liberty",
    "thomas": "Point Breeze",
    "brereton/28th": "Polish Hill",
    "braddock ave": "Point Breeze",
    "braddock ave": "Squirrel Hill South",
    "sennot st": "Central Oakland",
    "highland": "East Liberty",
    "o'hara bigelow bayard": "Central Oakland",
    "allegheny circle": "Central Allegheny",
    "3rd ave": "Central Business District",
    "south side neighborway": "South Side",
    "central lawrenceville neighborway": "Central Lawrenceville",
    "marshall": "Marshall-Shadeland",
    "marshall": "Brighton Heights",
    "bloomfield-friendship neighborway": "Bloomfield",
    "euclid neighborway": "East Liberty",
    "melwood gold neighborway": "Hazelwood",
    "reynolds neighborway": "Point Breeze",
    "california": "California-Kirkbride",
    "federal": "North Shore"
}

# Function to query the OSM
def get_pittsburgh_neighborhood(query):
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": f"{query}, Pittsburgh, PA",
        "format": "json",
        "addressdetails": 1,
        "limit": 1
    }
    headers = {
        "User-Agent": "BicycleLaneNeighborhoodFinder/1.0 (rgf21@pitt.edu)"
    }

    try:
        response = requests.get(url, params=params, headers=headers)
        data = response.json()
        if not data:
            return None

        address = data[0].get("address", {})
        return (
            address.get("neighbourhood") or 
            address.get("suburb") or 
            address.get("city_district")
        )
    except Exception as e:
        print(f"API error for {query}: {e}")
        return None

# Loads the data file
df = pd.read_csv("Bicycle pavement markings, 1980 to present - Existing.tsv", sep="\t")

# cleans up file
df = df[df["Street"].notna()]
df["Street"] = df["Street"].str.strip()
df["Cross Streets"] = df["Cross Streets"].fillna("").str.strip()

# Stores results
neighborhoods = []

# Goes row by row
for idx, row in df.iterrows():
    street = row["Street"]
    cross = row["Cross Streets"]

    # Lowercase keys for manual lookup
    key = street.lower().strip()
    if key in manual_neighborhoods:
        neighborhood = manual_neighborhoods[key]
        print(f"[Manual] {street} -> {neighborhood}")
        neighborhoods.append((neighborhood, street))
        continue

    # Checks for valid cross streets
    bad_terms = {"loop", "various", "through", "park", "trail", "path"}
    use_cross = cross and all(term not in cross.lower() for term in bad_terms)

    # Simplifies cross streets
    if use_cross:
        if " to " in cross:
            cross_simple = cross.split(" to ")[0]
        elif "/" in cross:
            cross_simple = cross.split("/")[0]
        else:
            cross_simple = cross
        cross_simple = cross_simple.strip()
        query = f"{street} and {cross_simple}"
    else:
        query = street

    print(f"Querying: {query}")
    neighborhood = get_pittsburgh_neighborhood(query)

    # Fallback in case of failiure
    if not neighborhood and use_cross:
        print(f"Fallback to just street: {street}")
        neighborhood = get_pittsburgh_neighborhood(street)

    if neighborhood:
        print(f"{query} -> {neighborhood}")
        neighborhoods.append((neighborhood, street))

    time.sleep(1)

# Creates summary of data
summary_df = pd.DataFrame(neighborhoods, columns=["Neighborhood", "Street"])
summary = summary_df.groupby("Neighborhood").size().reset_index(name="Bike Lanes")
summary.to_csv("neighborhood_bike_lane_counts.csv", index=False)

print("\n Done!")
print("Neighborhood summary -> 'neighborhood_bike_lane_counts.csv'")
# Out:
# [Manual] Resevoir Dr -> Highland Park
# Querying: Riverview Dr
# Riverview Dr -> Perry North
# Querying: Beechwood Blvd and Fifth Ave
# Fallback to just street: Beechwood Blvd
# Beechwood Blvd and Fifth Ave -> Squirrel Hill South
# Querying: Liberty Ave and Ligonier St
# Fallback to just street: Liberty Ave
# Liberty Ave and Ligonier St -> Bloomfield
# Querying: Birmingham Bridge and E Carson St
# Fallback to just street: Birmingham Bridge
# Birmingham Bridge and E Carson St -> South Oakland
# Querying: East Liberty Blvd and Negley Ave
# Fallback to just street: East Liberty Blvd
# East Liberty Blvd and Negley Ave -> Larimer
# Querying: Greenfield Rd and Pocusset St
# Fallback to just street: Greenfield Rd
# Greenfield Rd and Pocusset St -> Squirrel Hill South
# Querying: Wightman St and Forbes Ave
# Fallback to just street: Wightman St
# Wightman St and Forbes Ave -> Squirrel Hill South
# Querying: Beacon Ave and Wightman Ave
# Fallback to just street: Beacon Ave
# Beacon Ave and Wightman Ave -> Squirrel Hill South
# Querying: Penn Ave and 32nd St
# Fallback to just street: Penn Ave
# Penn Ave and 32nd St -> Lower Lawrenceville
# Querying: Forbes Ave and Margaret Morrison St
# Fallback to just street: Forbes Ave
# Forbes Ave and Margaret Morrison St -> South Oakland
# Querying: Forbes Ave and Beechwood
# Fallback to just street: Forbes Ave
# Forbes Ave and Beechwood -> South Oakland
# Querying: Dallas Ave and WilkinsAve
# Fallback to just street: Dallas Ave
# Dallas Ave and WilkinsAve -> Homewood West
# Querying: Hamilton Ave and Dallas Ave
# Fallback to just street: Hamilton Ave
# Hamilton Ave and Dallas Ave -> Brushton
# Querying: Wilkins Ave and Beechwood Ave
# Fallback to just street: Wilkins Ave
# Wilkins Ave and Beechwood Ave -> Squirrel Hill North
# [Manual] Highland Ave -> East Liberty
# Querying: Penn Ave and 31st - 34th
# Fallback to just street: Penn Ave
# Penn Ave and 31st - 34th -> Lower Lawrenceville
# Querying: Friendship Ave and Penn Ave - Pearl
# Fallback to just street: Friendship Ave
# Friendship Ave and Penn Ave - Pearl -> Bloomfield
# Querying: Friendship Ave and Gross - Negley
# Fallback to just street: Friendship Ave
# Friendship Ave and Gross - Negley -> Bloomfield
# Querying: Millvale Ave and Centre Ave
# Fallback to just street: Millvale Ave
# Millvale Ave and Centre Ave -> Bloomfield
# Querying: Millvale Ave and Bridge
# Fallback to just street: Millvale Ave
# Millvale Ave and Bridge -> Bloomfield
# Querying: Millvale Ave and Liberty
# Fallback to just street: Millvale Ave
# Millvale Ave and Liberty -> Bloomfield
# Querying: Centre Ave and Milvale
# Fallback to just street: Centre Ave
# Centre Ave and Milvale -> Schenley Farms Historic District
# Querying: Neville St and Center Ave
# Fallback to just street: Neville St
# Neville St and Center Ave -> Lower Lawrenceville
# Querying: Ellsworth Ave and Neville St- S. Aiken
# Fallback to just street: Ellsworth Ave
# Ellsworth Ave and Neville St- S. Aiken -> Shadyside
# Querying: Merchant St and Ridge Ave
# Fallback to just street: Merchant St
# Merchant St and Ridge Ave -> North Shore
# Querying: Brighton Rd and West Ohio St
# Fallback to just street: Brighton Rd
# Brighton Rd and West Ohio St -> Marshall-Shadeland
# Querying: Liberty Ave and Ligonier St
# Fallback to just street: Liberty Ave
# Liberty Ave and Ligonier St -> Bloomfield
# Querying: W. Ohio St and Merchant St
# Fallback to just street: W. Ohio St
# W. Ohio St and Merchant St -> Allegheny West
# Querying: Brighton Rd and Charles St
# Fallback to just street: Brighton Rd
# Brighton Rd and Charles St -> Marshall-Shadeland
# Querying: Millvale Ave and Bridge
# Fallback to just street: Millvale Ave
# Millvale Ave and Bridge -> Bloomfield
# Querying: Friendship Ave and Pearl
# Fallback to just street: Friendship Ave
# Friendship Ave and Pearl -> Bloomfield
# Querying: Neville Ave and Fifth
# Fallback to just street: Neville Ave
# Neville Ave and Fifth -> Shadyside
# Querying: E Carson St and Hot Metal St
# Fallback to just street: E Carson St
# E Carson St and Hot Metal St -> South Side Flats
# Querying: Ellsworth and Aiken
# Fallback to just street: Ellsworth
# Ellsworth and Aiken -> Shadyside
# Querying: Butler St and Penn
# Fallback to just street: Butler St
# Butler St and Penn -> Lawrenceville
# Querying: E Ohio St and Cedar
# Fallback to just street: E Ohio St
# E Ohio St and Cedar -> East Allegheny
# [Manual] Thomas -> Point Breeze
# Querying: Reynolds and S Dallas
# Fallback to just street: Reynolds
# Reynolds and S Dallas -> Point Breeze
# Querying: Meade and Lexington
# Fallback to just street: Meade
# Meade and Lexington -> Homewood
# Querying: Homewood and Reynolds
# Fallback to just street: Homewood
# Homewood and Reynolds -> Homewood
# Querying: S Bouquet St and Joncaire
# Fallback to just street: S Bouquet St
# S Bouquet St and Joncaire -> Oakland
# [Manual] Brereton/28th -> Polish Hill
# Querying: Dobson and Brereton
# Fallback to just street: Dobson
# Dobson and Brereton -> Polish Hill
# [Manual] Braddock Ave -> Squirrel Hill South
# [Manual] Sennot St -> Central Oakland
# Querying: Meyran Ave and Fresco
# Fallback to just street: Meyran Ave
# Meyran Ave and Fresco -> Oakland
# Querying: Coltart and Zulema
# Fallback to just street: Coltart
# Coltart and Zulema -> Oakland
# Querying: Atwood St and Dawson
# Fallback to just street: Atwood St
# Atwood St and Dawson -> Oakland
# [Manual] Highland -> East Liberty
# Querying: Penn Ave and 11th - 16th
# Fallback to just street: Penn Ave
# Penn Ave and 11th - 16th -> Lower Lawrenceville
# Querying: Mairdale
# Mairdale -> Perry North
# Querying: Pocusset and Greenfield
# Fallback to just street: Pocusset
# Pocusset and Greenfield -> Squirrel Hill South
# Querying: Negley Run and Washington Blvd
# Fallback to just street: Negley Run
# Negley Run and Washington Blvd -> East Liberty
# Querying: Centre Ave and ELB
# Fallback to just street: Centre Ave
# Centre Ave and ELB -> Schenley Farms Historic District
# Querying: Morewood Ave and Millvale
# Fallback to just street: Morewood Ave
# Morewood Ave and Millvale -> Bloomfield
# Querying: Penn Ave and Stanwix St
# Fallback to just street: Penn Ave
# Penn Ave and Stanwix St -> Lower Lawrenceville
# Querying: Schenley Dr and Schenley Plaza
# Fallback to just street: Schenley Dr
# Schenley Dr and Schenley Plaza -> Panther Hollow
# Querying: Saline St
# Saline St -> Squirrel Hill South
# Querying: E Carson and 26th
# Fallback to just street: E Carson
# E Carson and 26th -> South Side Flats
# Querying: 6th and Penn
# 6th and Penn -> Cultural District
# Querying: Federal St and Bridge
# Fallback to just street: Federal St
# Federal St and Bridge -> Allegheny Center
# Querying: Roberto Clemente and bridge deck
# Fallback to just street: Roberto Clemente
# Roberto Clemente and bridge deck -> North Shore
# Querying: 40th St and Liberty
# Fallback to just street: 40th St
# 40th St and Liberty -> Bloomfield
# Querying: Bigelow and O'Hara
# Fallback to just street: Bigelow
# Bigelow and O'Hara -> Greenfield
# [Manual] O'Hara Bigelow Bayard -> Central Oakland
# Querying: Schenley Drive and Schenley Drive Extension
# Fallback to just street: Schenley Drive
# Schenley Drive and Schenley Drive Extension -> Panther Hollow
# Querying: East Street and Lareda street
# Fallback to just street: East Street
# East Street and Lareda street -> Perry North
# Querying: Howard Street and North Avenue
# Fallback to just street: Howard Street
# Howard Street and North Avenue -> East Allegheny
# Querying: One Wild Pl and Butler St
# Fallback to just street: One Wild Pl
# One Wild Pl and Butler St -> Highland Park
# Querying: East St and Suffolk
# Fallback to just street: East St
# East St and Suffolk -> Perry North
# Querying: E Ohio St and Chestnut
# Fallback to just street: E Ohio St
# E Ohio St and Chestnut -> East Allegheny
# Querying: Federal St and North
# Fallback to just street: Federal St
# Federal St and North -> Allegheny Center
# Querying: Forbes Ave and Bigelow Blvd
# Fallback to just street: Forbes Ave
# Forbes Ave and Bigelow Blvd -> South Oakland
# Querying: Phineas St and Chestnut
# Fallback to just street: Phineas St
# Phineas St and Chestnut -> Troy Hill
# Querying: Federal St and North
# Fallback to just street: Federal St
# Federal St and North -> Allegheny Center
# [Manual] Allegheny Circle -> Central Allegheny
# Querying: Negley Ave and Howe St
# Fallback to just street: Negley Ave
# Negley Ave and Howe St -> Shadyside
# Querying: Bigelow Blvd and Fifth
# Fallback to just street: Bigelow Blvd
# Bigelow Blvd and Fifth -> Schenley Farms Historic District
# Querying: Greenfield Rd and Pocusset St
# Fallback to just street: Greenfield Rd
# Greenfield Rd and Pocusset St -> Squirrel Hill South
# Querying: Riverview Ave
# Riverview Ave -> Perry North
# Querying: Smithfield St and Ft Pitt
# Fallback to just street: Smithfield St
# Smithfield St and Ft Pitt -> South Shore
# Querying: Wood St and Ft Pitt
# Fallback to just street: Wood St
# Wood St and Ft Pitt -> Cultural District
# Querying: Ft Pitt and Smithfield
# Fallback to just street: Ft Pitt
# Ft Pitt and Smithfield -> Gateway
# [Manual] 3rd Ave -> Central Business District
# Querying: Blair St
# Blair St -> Glenwood
# Querying: Hazelwood Ave and Blair St
# Fallback to just street: Hazelwood Ave
# Hazelwood Ave and Blair St -> Hazelwood
# Querying: Forbes Ave and Craig St
# Fallback to just street: Forbes Ave
# Forbes Ave and Craig St -> South Oakland
# Querying: Broad St and Centre Ave
# Fallback to just street: Broad St
# Broad St and Centre Ave -> East Liberty
# Querying: East St and Evergreen
# Fallback to just street: East St
# East St and Evergreen -> Perry North
# Querying: Black St and Aiken
# Fallback to just street: Black St
# Black St and Aiken -> Garfield
# Querying: Lytle St and Hazelwood Ave
# Fallback to just street: Lytle St
# Lytle St and Hazelwood Ave -> Glenwood
# [Manual] South Side Neighborway -> South Side
# [Manual] Central Lawrenceville Neighborway -> Central Lawrenceville
# [Manual] Marshall -> Brighton Heights
# [Manual] Bloomfield-Friendship Neighborway -> Bloomfield
# [Manual] Euclid Neighborway -> East Liberty
# Querying: Stanwix St and 3rd Ave
# Fallback to just street: Stanwix St
# Stanwix St and 3rd Ave -> Gateway
# Querying: Liberty Ave
# Liberty Ave -> Bloomfield
# [Manual] Melwood Gold Neighborway -> Hazelwood
# Querying: 6th Street and Ft. Duquesne
# Fallback to just street: 6th Street
# 6th Street and Ft. Duquesne -> Cultural District
# Querying: Negley Run Blvd and Washington
# Fallback to just street: Negley Run Blvd
# Negley Run Blvd and Washington -> East Liberty
# [Manual] Reynolds Neighborway -> Point Breeze
# Querying: Smallman and 17th
# Fallback to just street: Smallman
# Smallman and 17th -> Strip District
# Querying: Brighton Rd and Ridge
# Fallback to just street: Brighton Rd
# Brighton Rd and Ridge -> Marshall-Shadeland
# Querying: Brighton Rd and North
# Fallback to just street: Brighton Rd
# Brighton Rd and North -> Marshall-Shadeland
# Querying: Columbus Ave and Fulton
# Fallback to just street: Columbus Ave
# Columbus Ave and Fulton -> Manchester
# [Manual] California -> California-Kirkbride
# Querying: W Ohio St and Merchant
# Fallback to just street: W Ohio St
# W Ohio St and Merchant -> Allegheny West
# Querying: East Liberty Blvd and Hamilton
# Fallback to just street: East Liberty Blvd
# East Liberty Blvd and Hamilton -> Larimer
# Querying: Serpentine and Bartlett
# Fallback to just street: Serpentine
# Serpentine and Bartlett -> Squirrel Hill South
# Querying: Pennsylvania and Allegheny
# Fallback to just street: Pennsylvania
# Pennsylvania and Allegheny -> Hamnett Place
# Querying: Pennsylvania and Manhattan
# Fallback to just street: Pennsylvania
# Pennsylvania and Manhattan -> Hamnett Place
# Querying: Juniata and Chateau
# Fallback to just street: Juniata
# Juniata and Chateau -> Point Breeze
# Querying: Manhattan and Juniata
# Fallback to just street: Manhattan
# Manhattan and Juniata -> Manchester
# Querying: Fulton and Juniata
# Fallback to just street: Fulton
# Fulton and Juniata -> Highland Park
# Querying: Allegheny and Pennsylvania
# Allegheny and Pennsylvania -> Highland Park
# [Manual] Federal -> North Shore
# Querying: Bartlett St and Murdoch
# Fallback to just street: Bartlett St
# Bartlett St and Murdoch -> Squirrel Hill South
# Querying: Melwood Ave and Centre
# Fallback to just street: Melwood Ave
# Melwood Ave and Centre -> Polish Hill
# Querying: S 18th St
# S 18th St -> Billy Buck Hill
# Querying: S Aiken Ave and Liberty
# Fallback to just street: S Aiken Ave
# S Aiken Ave and Liberty -> Bloomfield
# Querying: Ellsworth and Neville
# Fallback to just street: Ellsworth
# Ellsworth and Neville -> Shadyside
# Querying: Stanton and McCandless
# Fallback to just street: Stanton
# Stanton and McCandless -> Stanton Heights
# Querying: Perrysville and Baytree
# Fallback to just street: Perrysville
# Perrysville and Baytree -> Perry North
# Querying: Forbes and Beechwood
# Fallback to just street: Forbes
# Forbes and Beechwood -> Oakland
# Querying: Beacon and Beechwood
# Fallback to just street: Beacon
# Beacon and Beechwood -> Squirrel Hill South
# Querying: Shaw and Beacon
# Fallback to just street: Shaw
# Shaw and Beacon -> Squirrel Hill South
# Querying: Bartlett and Beacon
# Fallback to just street: Bartlett
# Bartlett and Beacon -> Squirrel Hill South
# Querying: Woods Run
# Woods Run -> Woods Run
# Querying: Frew St and Schenley
# Fallback to just street: Frew St
# Frew St and Schenley -> Squirrel Hill South
# Querying: Friendship Ave and S St. Clair
# Fallback to just street: Friendship Ave
# Friendship Ave and S St. Clair -> Bloomfield
# Querying: S Euclid Ave and Centre
# Fallback to just street: S Euclid Ave
# S Euclid Ave and Centre -> East Liberty
# Querying: N Euclid Ave and Penn
# Fallback to just street: N Euclid Ave
# N Euclid Ave and Penn -> Highland Park
# Querying: Station Street and N Euclid
# Fallback to just street: Station Street
# Station Street and N Euclid -> East Liberty
# Querying: Penn Ave and Negley
# Fallback to just street: Penn Ave
# Penn Ave and Negley -> Lower Lawrenceville
# Querying: Greenfield Ave and Saline
# Fallback to just street: Greenfield Ave
# Greenfield Ave and Saline -> Four Mile Run
# Querying: Stanton Ave and Chislett
# Fallback to just street: Stanton Ave
# Stanton Ave and Chislett -> Highland Park
# Querying: Morewood Ave and Fifth Ave
# Fallback to just street: Morewood Ave
# Morewood Ave and Fifth Ave -> Bloomfield
#
#  Done!
# Neighborhood summary -> 'neighborhood_bike_lane_counts.csv'
